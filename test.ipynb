# %%
# Packages already installed - this cell can be skipped
# %pip install opencv-python pytesseract

# %%
# %sh pip install --upgrade numpy pandas pytesseract

# %%
# %restart_python

# %%
import cv2

# %%
# Reinstall pandas to match the upgraded numpy version
import sys
# !{sys.executable} -m pip install --upgrade --force-reinstall pandas

import pytesseract

# %%
def image_to_text(image_path):
    img = cv2.imread(image_path)
    text = pytesseract.image_to_string(img)
    return text

# %%
# ERROR: Tesseract OCR binary is not installed on Serverless compute
# pytesseract requires the system-level Tesseract binary, which cannot be installed on Serverless
# 
# Solutions:
# 1. Use a cluster with "Unrestricted" cluster policy where you can install via init script
# 2. Use Databricks SQL AI functions like ai_extract_text() for OCR
# 3. Use cloud OCR APIs (Azure Computer Vision, AWS Textract, Google Vision)
# 
text_out = image_to_text("/Workspace/Users/praveenkottari.iisc@gmail.com/praveen/OCR/input.png")
